# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("nobetter.csv"))
df.head()
# Out:
#    Population % Change  2010 Population  % Foreign Born  Veterans  \
# 0                  1.5            54571             1.6      5922
# 1                  9.8           182265             3.6     19346
# 2                 -2.1            27457             2.9      2120
# 3                 -1.8            22915             1.2      1327
# 4                  0.7            57322             4.3      4540
#
#    Mean Travel Time  Median Household Income  Below Poverty Level  \
# 0              26.2                    53682                 12.1
# 1              25.9                    50221                 13.9
# 2              24.6                    32911                 26.7
# 3              27.6                    36447                 18.1
# 4              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms  % Asian-owned Firms    ...     \
# 0                   4067                 15.2                  1.3    ...
# ...

# %%
df.columns
# Out:
# Index(['Population % Change', '2010 Population', '% Foreign Born', 'Veterans',
#        'Mean Travel Time', 'Median Household Income', 'Below Poverty Level',
#        'Total Number of Firms', '% Black-owned Firms', '% Asian-owned Firms',
#        '% Hispanic-owned Firms', '% Women-owned Firms',
#        'Manufacturers Shipments ($1000)', 'Retail Sales ($1000)',
#        'Retail Sales per Capita', 'Building permits',
#        'Land Area (Square Miles)', 'Population per Square Mile',
#        'No Preference', 'Uncommitted', 'Ben Carson', 'Bernie Sanders',
#        'Carly Fiorina', 'Chris Christie', 'Donald Trump', 'Hillary Clinton',
#        'Jeb Bush', 'John Kasich', 'Marco Rubio', 'Martin OMalley',
#        'Mike Huckabee', 'Rand Paul', 'Rick Santorum', 'Ted Cruz'],
#       dtype='object')

# %%
df_clean = df.drop(columns=["No Preference", "Uncommitted", "Ben Carson", "Bernie Sanders", "Carly Fiorina", "Chris Christie", "Hillary Clinton"])
df_clean.head()
# Out:
#    Population % Change  2010 Population  % Foreign Born  Veterans  \
# 0                  1.5            54571             1.6      5922
# 1                  9.8           182265             3.6     19346
# 2                 -2.1            27457             2.9      2120
# 3                 -1.8            22915             1.2      1327
# 4                  0.7            57322             4.3      4540
#
#    Mean Travel Time  Median Household Income  Below Poverty Level  \
# 0              26.2                    53682                 12.1
# 1              25.9                    50221                 13.9
# 2              24.6                    32911                 26.7
# 3              27.6                    36447                 18.1
# 4              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms  % Asian-owned Firms    ...     \
# 0                   4067                 15.2                  1.3    ...
# ...

# %%
df_cleaner = df_clean.drop(columns=["Jeb Bush", "John Kasich", "Marco Rubio", "Martin OMalley", "Mike Huckabee", 'Rand Paul', 'Rick Santorum', 'Ted Cruz'])
df_cleaner
# Out:
#       Population % Change  2010 Population  % Foreign Born  Veterans  \
# 0                     1.5            54571             1.6      5922
# 1                     9.8           182265             3.6     19346
# 2                    -2.1            27457             2.9      2120
# 3                    -1.8            22915             1.2      1327
# 4                     0.7            57322             4.3      4540
# 5                    -1.4            10914             5.4       636
# 6                    -3.1            20947             0.8      1497
# 7                    -2.3           118572             2.4     11385
# 8                    -0.3            34215             1.1      2691
# 9                     0.2            25989             0.7      2174
# 10                    0.7            43643             5.2      3308
# 11                   -3.9            13859             0.3       938
# 12                   -3.5            25833             0.3      1583
# ...

# %%
target = df_cleaner["Donald Trump"]
target_names = ["Votes"]

# %%
data = df_cleaner.drop("Donald Trump", axis=1)
feature_names = data.columns
data.head()
# Out:
#    Population % Change  2010 Population  % Foreign Born  Veterans  \
# 0                  1.5            54571             1.6      5922
# 1                  9.8           182265             3.6     19346
# 2                 -2.1            27457             2.9      2120
# 3                 -1.8            22915             1.2      1327
# 4                  0.7            57322             4.3      4540
#
#    Mean Travel Time  Median Household Income  Below Poverty Level  \
# 0              26.2                    53682                 12.1
# 1              25.9                    50221                 13.9
# 2              24.6                    32911                 26.7
# 3              27.6                    36447                 18.1
# 4              33.9                    44145                 15.8
#
#    Total Number of Firms  % Black-owned Firms  % Asian-owned Firms  \
# 0                   4067                 15.2                  1.3
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.008571428571428572

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.018571428571428572

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.07120817547077964, 'Land Area (Square Miles)'),
#  (0.07067552833949149, 'Median Household Income'),
#  (0.06827048586762136, 'Mean Travel Time'),
#  (0.06813084754054144, 'Retail Sales per Capita'),
#  (0.06656618590866657, 'Population % Change'),
#  (0.06623015465830673, 'Below Poverty Level'),
#  (0.06471418109706968, 'Population per Square Mile'),
#  (0.06372985153056165, '% Foreign Born'),
#  (0.06315325779346968, 'Veterans'),
#  (0.061171800880225675, '2010 Population'),
#  (0.06052842747078114, 'Retail Sales ($1000)'),
#  (0.05992306204016391, 'Total Number of Firms'),
#  (0.05810087161098434, 'Building permits'),
#  (0.05072297294114673, '% Women-owned Firms'),
#  (0.04121211883831892, 'Manufacturers Shipments ($1000)'),
#  (0.02397344955477525, '% Black-owned Firms'),
#  (0.02180461571881089, '% Hispanic-owned Firms'),
#  (0.019884012738284967, '% Asian-owned Firms')]
